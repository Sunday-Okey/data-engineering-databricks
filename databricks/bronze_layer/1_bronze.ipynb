# %% [markdown]
# ## Volumes

# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA labuser14614688_1776181907;

# %%
# %sql
SELECT current_catalog(), current_schema()

# %%
# %sql
CREATE VOLUME IF NOT EXISTS bronze_volume;

# %%
# %sql
SHOW VOLUMES;

# %%
# %sql
SELECT *
FROM csv.`/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/fact_sales.csv`

# %% [markdown]
# ## DBUTILS

# %%
dbutils.help()

# %%
dbutils.help('fs')

# %%
display(dbutils.fs.ls('/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume'))

# %%
dbutils.fs.mkdirs("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/customers")

# %%
dbutils.fs.cp("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/fact_sales.csv", "/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/customers/")

# %%
dbutils.fs.rm("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/fact_sales.csv")

# %%
dbutils.fs.mkdirs("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/sales")

# %%
dbutils.fs.cp("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/customers/fact_sales.csv", "/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/sales/")

# %%
dbutils.fs.put("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/customers/text.txt","Hello World", overwrite=True)

# %%
all_items = dbutils.fs.ls("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/customers/")
all_items

# %%
[i.name for i in all_items]

# %%
dbutils.widgets.text("name", "John")

name = dbutils.widgets.get("name")
print(name)

# %%
dbutils.fs.rm("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/sales/", True)

# %%
# %sql
DROP VOLUME IF EXISTS bronze_volume;
    
SHOW VOLUMES;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS bronze_volume;
    
SHOW VOLUMES;

# %%
for dir in ['customers', 'sales']:
    dbutils.fs.mkdirs(f"/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/{dir}/")

# %%
dbutils.fs.rm("/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume/orders/", True)

# %%
display(dbutils.fs.ls('/Volumes/dbacademy/labuser14614688_1776181907/bronze_volume'))
