# %% [markdown]
# ![image.png](attachment:c8d6f49a-dc6f-45ce-9c22-133c9f66cfa0.png)

# %% [markdown]
# ![image.png](attachment:7bfd75a5-9693-451b-9288-c5fa8c7b8dd0.png)

# %% [markdown]
# ![image.png](attachment:1c815431-888f-4bf9-95de-9f905ff1fe80.png)

# %% [markdown]
# ![image.png](attachment:d3a0279f-6042-4a7d-a925-7e971d0e7f6b.png)

# %% [markdown]
# ![image.png](attachment:ca907eb2-5175-44b6-a635-b41aca8d2281.png)

# %% [markdown]
# ![image.png](attachment:831ab67b-ade1-451b-ac09-e307cdc0a793.png)

# %% [markdown]
# ![image.png](attachment:0b9d734f-18fe-4326-addd-01dbce1aa282.png)
