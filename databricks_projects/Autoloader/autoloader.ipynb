# %%
# %sql 
USE CATALOG dbacademy;
USE SCHEMA labuser14614688_1776258766;

# %%
df = spark.readStream.format("cloudFiles")\
    .option("cloudFiles.format", "csv")\
    .option("cloudFiles.schemaLocation", "/Volumes/dbacademy/labuser14614688_1776258766/autovol/destination/checkpoint/")\
    .option("cloudFiles.schemaEvolutionMode", "addNewColumns")\
    .option("cloudFiles.maxFilesPerTrigger", 1)\
    .load("/Volumes/dbacademy/labuser14614688_1776258766/autovol/raw/")

# %%
display(df)

# %%
df.writeStream.outputMode("append")\
    .option("checkpointLocation", "/Volumes/dbacademy/labuser14614688_1776258766/autovol/destination/checkpoint/")\
    .option("mergeSchema", "true")\
    .trigger(once=True)\
    .start("/Volumes/dbacademy/labuser14614688_1776258766/autovol/destination/data/")

# %%
df = spark.read.format('delta')\
    .load("/Volumes/dbacademy/labuser14614688_1776258766/autovol/destination/data/")

display(df)

# %% [markdown]
# ## COPY INTO

# %%
# %sql
SELECT *
FROM parquet.`/Volumes/dbacademy/labuser14614688_1776258766/autovol/copyinto/part-00000-tid-1800520145580676501-2fb00642-a896-4599-9957-2c7260f04aa7-132-1.c000.snappy.parquet`

# %%
# %sql
CREATE TABLE IF NOT EXISTS orders (
  order_id INT,
  customer_id INT,
  order_date DATE,
  order_amount DOUBLE,
  order_status STRING
)

# %%
# %sql
COPY INTO orders
FROM '/Volumes/dbacademy/labuser14614688_1776258766/autovol/copyinto/'
FILEFORMAT = PARQUET
FORMAT_OPTIONS('mergeSchema' = 'true')
COPY_OPTIONS('mergeSchema' = 'true')

# %%
# %sql
SELECT * 
FROM orders;
