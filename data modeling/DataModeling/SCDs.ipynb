# %% [markdown]
# ### **SCD TYPE - 1**

# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA labuser14586003_1778076074;

# %%
# %sql
CREATE TABLE scdtyp1_source
(
  prod_id INT,
  prod_name STRING,
  prod_cat STRING,
  processDate DATE
)

# %%
# %sql
INSERT INTO scdtyp1_source
VALUES
(1,'prod1','cat1',CURRENT_DATE()),
(2,'prod2','cat2',CURRENT_DATE()),
(3,'prod3','cat3',CURRENT_DATE())

# %%
# %sql
CREATE TABLE scdtyp1_table
(
  prod_id INT,
  prod_name STRING,
  prod_cat STRING,
  processDate DATE
)

# %%
spark.sql("select * from scdtyp1_source").createOrReplaceTempView("src")

# %%
# %sql
MERGE INTO scdtyp1_table AS trg
USING src
ON src.prod_id = trg.prod_id
WHEN MATCHED AND src.processDate >= trg.processDate THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *

# %%
# %sql
SELECT * FROM scdtyp1_table

# %%
# %sql
UPDATE scdtyp1_source SET prod_cat = 'newcategory'
WHERE prod_id = 3

# %% [markdown]
# # **SCD TYPE 2**

# %% [markdown]
# ### **Source Creation**

# %%
# %sql
CREATE TABLE scdtyp2_source
(
  prod_id INT,
  prod_name STRING,
  prod_cat STRING,
  processDate DATE
)

# %%
# %sql
INSERT INTO scdtyp2_source
VALUES
(1,'prod1','cat1',CURRENT_DATE()),
(2,'prod2','cat2',CURRENT_DATE()),
(3,'prod3','cat3',CURRENT_DATE())

# %% [markdown]
# ### **Target Table**

# %%
# %sql
CREATE TABLE scdtype2_table
(
  prod_id INT,
  prod_name STRING,
  prod_cat STRING,
  processDate DATE,
  start_date DATE,
  end_date DATE,
  is_current STRING
)

# %% [markdown]
# **Adding additional 3 columns for SCD Type - 2**

# %%
spark.sql("""SELECT *,
        current_timestamp as start_date,
        CAST('3000-01-01' AS TIMESTAMP) as end_date,
        'Y' as is_current
FROM scdtyp2_source""").createOrReplaceTempView("src")

# %%
# %sql
SELECT *
FROM src

# %% [markdown]
# ### **SCD TYPE 2 MEGE CONDISTIONS**
#
# **MERGE-1** : This command will check if we have any data in the target table that is updated in the source, and will mark it as expired.

# %%
# %sql
MERGE INTO scdtype2_table AS trg
USING src 
ON src.prod_id = trg.prod_id
AND trg.is_current = 'Y'

-- When We have New Data With Updates
WHEN MATCHED AND (
  src.prod_cat <> trg.prod_cat OR
  src.processDate <> trg.processDate OR
  src.prod_name <> trg.prod_name
) THEN 
  UPDATE SET 
    trg.end_date = current_timestamp(),
    trg.is_current = 'N'

# %% [markdown]
# **MERGE-2** : This command will bring all the non-expired commands bcz we have filter of "is_current = 'Y'". So, this will not bring the updated records as well bcz previous MERGE command marked it as expired. So all the new records [including updated] will be inserted in this MERGE.

# %%
# %sql
MERGE INTO scdtype2_table AS trg
USING src 
ON trg.prod_id = src.prod_id 
AND trg.is_current = 'Y' 

WHEN NOT MATCHED THEN INSERT 
(
  prod_id,
  prod_name,
  prod_cat,
  processDate,
  start_date,
  end_date,
  is_current
) VALUES (
  src.prod_id,
  src.prod_name,
  src.prod_cat,
  src.processDate,
  src.start_date,
  src.end_date,
  src.is_current
)

# %%
# %sql
SELECT * FROM scdtype2_table
