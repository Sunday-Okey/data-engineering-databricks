-- %%
USE CATALOG dbacademy;
USE SCHEMA labuser14586003_1780512805;

-- %%
CREATE TABLE IF NOT EXISTS employees (
  id INT,
  name STRING,
  department STRING,
  salary INT
);

-- %%
SELECT *
FROM employees;

-- %%
SHOW TABLES;

-- %%
ALTER TABLE employees_old RENAME TO employees;
-- ALTER TABLE employees RENAME TO employees_old;

-- %%
ALTER TABLE employees ADD COLUMN dob date;

-- %%
SELECT *
FROM employees;

-- %%
ALTER TABLE employees SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE employees
RENAME COLUMN doj TO dob;

-- %%
INSERT INTO employees
VALUES (1, 'John', 'Sales', 50000, '1990-01-01'),
       (2, 'Jane', 'Marketing', 60000, '1985-05-15'),
       (3, 'Bob', 'Engineering', 70000, '1980-08-22'),
       (4, 'Alice', 'Engineering', 80000, '1995-03-10'),
       (5, 'Charlie', 'Sales', 55000, '1992-12-01');

SELECT *
FROM employees;

-- %%
SELECT to_date('2001-05-12', 'yyyy-MM-dd') AS dob
